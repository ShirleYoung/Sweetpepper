# %%
# !python tcore/scripts/train_augumented.py --ckpt_path TCoRe_sweet_try/checkpoints/pretrained_model.ckpt   #train Tcore with augmented dataset
# Out:
# /root/anaconda3/envs/tcore/lib/python3.9/site-packages/MinkowskiEngine/__init__.py:36: UserWarning: The environment variable `OMP_NUM_THREADS` not set. MinkowskiEngine will automatically set `OMP_NUM_THREADS=16`. If you want to set `OMP_NUM_THREADS` manually, please export it on the command line before running a python script. e.g. `export OMP_NUM_THREADS=12; python your_program.py`. It is recommended to set it below 24.
#   warnings.warn(
# Using FRUITS dataset
# IGGFruitDatasetModule begins
# /home/Sweetpepper/TCoRe_sweet_try/tcore/scripts/train_augumented.py
# /home/Sweetpepper/TCoRe_sweet_try
# /home/Sweetpepper/sweetpepper_dataset/shape_completion_challenge/train_augmented_dataset.pkl
# 从 ../sweetpepper_dataset/shape_completion_challenge/train_augmented_dataset.pkl 加载增强后的训练数据集
# /home/Sweetpepper/TCoRe_sweet_try/tcore/scripts/train_augumented.py
# /home/Sweetpepper/TCoRe_sweet_try
# 从 ../sweetpepper_dataset/shape_completion_challenge/val_dataset.pkl 加载 val 数据集
# val 样本数据结构:
# ...

# %%
# !python tcore/scripts/test.py  #generate tcore_result with trained model
# Out:
# /root/anaconda3/envs/tcore/lib/python3.9/site-packages/MinkowskiEngine/__init__.py:36: UserWarning: The environment variable `OMP_NUM_THREADS` not set. MinkowskiEngine will automatically set `OMP_NUM_THREADS=16`. If you want to set `OMP_NUM_THREADS` manually, please export it on the command line before running a python script. e.g. `export OMP_NUM_THREADS=12; python your_program.py`. It is recommended to set it below 24.
#   warnings.warn(
# Using FRUITS dataset
# IGGFruitDatasetModule begins
# 从 ../sweetpepper_dataset/shape_completion_challenge/train_dataset.pkl 加载 train 数据集
# train 样本数据结构:
# Shape of points: (50000, 3)
# Shape of gt_points: (28809, 3)
# points: <class 'numpy.ndarray'>
# colors: <class 'numpy.ndarray'>
# extra:
#   gt_points: <class 'numpy.ndarray'>
#   gt_normals: <class 'numpy.ndarray'>
# filename: <class 'str'>
# Shape of points: (50000, 3)
# Shape of gt_points: (28809, 3)
# /home/sweetpepper_dataset/shape_completion_challenge/train/lab37
# ...
