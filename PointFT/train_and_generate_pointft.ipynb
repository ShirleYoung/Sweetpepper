# %%
# !python train_sweetpepper.py -c PointFT/cfgs/PointFT.yaml   #train pointFT
# Out:
# /home/Sweetpepper/PointFT
# /home/Sweetpepper/PointFT/cfgs/PointFT.yaml
# save_path: log/
# INFO - 2024-09-06 08:45:43,606 - train_sweetpepper2 - Munch({'batch_size': 1, 'workers': 2, 'nepoch': 400, 'model_name': 'PointFT', 'load_model': './log/Pointft_cd_debug_pcn/model_pcn.pth', 'start_epoch': 0, 'num_points': 2048, 'work_dir': 'log/', 'flag': 'debug', 'loss': 'cd', 'manual_seed': None, 'step_interval_to_print': 100, 'epoch_interval_to_save': 1, 'epoch_interval_to_val': 1, 'lr': 0.0001, 'lr_decay': True, 'lr_decay_interval': 40, 'lr_decay_rate': 0.7, 'lr_step_decay_epochs': None, 'lr_step_decay_rates': None, 'lr_clip': 1e-06, 'optimizer': 'Adam', 'weight_decay': 0, 'betas': '0.9, 0.999', 'device': '0', 'data_source': '../sweetpepper_dataset/shape_completion_challenge', 'dataset': 'iggfruit', 'save_vis': False})
# 从 ../sweetpepper_dataset/shape_completion_challenge/train_dataset_pft.pkl 加载 train 数据集
# train 样本数据结构:
#   label: <class 'int'>
# ...

# %%
# !python test_sp_generate.py -c PointFT/cfgs/PointFT.yaml   #generate pointft_result from trained model
# Out:
# 从 ../sweetpepper_dataset/shape_completion_challenge/test_dataset_pft.pkl 加载 test 数据集
# test 样本数据结构:
#   label: <class 'int'>
#   points: <class 'numpy.ndarray'>, shape: (2048, 3)
#   gt_points: <class 'numpy.ndarray'>, shape: (2048, 3)
# Loaded compiled 3D CUDA chamfer distance
# Batch x: inputs shape = torch.Size([1, 3, 2048])
# Batch x: out shape = torch.Size([1, 2048, 3])
# Saved point cloud to ../pointft_result/p3.ply
# Batch x: inputs shape = torch.Size([1, 3, 2048])
# Batch x: out shape = torch.Size([1, 2048, 3])
# Saved point cloud to ../pointft_result/p1.ply
# Batch x: inputs shape = torch.Size([1, 3, 2048])
# Batch x: out shape = torch.Size([1, 2048, 3])
# Saved point cloud to ../pointft_result/p44.ply
# Batch x: inputs shape = torch.Size([1, 3, 2048])
# Batch x: out shape = torch.Size([1, 2048, 3])
# Saved point cloud to ../pointft_result/p25.ply
# Batch x: inputs shape = torch.Size([1, 3, 2048])
# Batch x: out shape = torch.Size([1, 2048, 3])
# ...
